# %%
import numpy as np

# %%
classes = ["alimentos", "vestuário", "esportes"]

# %%
embeddings = {
    # Alimentos
    "arroz":        np.array([0.9, 0.1, 0.0]),
    "feijao":       np.array([0.9, 0.1, 0.0]),
    "carne":        np.array([0.8, 0.2, 0.0]),
    "frango":       np.array([0.8, 0.2, 0.0]),
    "macarrao":     np.array([0.7, 0.3, 0.0]),
    "salada":       np.array([0.6, 0.4, 0.0]),
    "fruta":        np.array([0.5, 0.5, 0.0]),
    "comida":       np.array([0.8, 0.2, 0.0]),

    # Vestuário
    "camiseta":     np.array([0.0, 0.9, 0.1]),
    "camisa":       np.array([0.0, 0.85, 0.15]),
    "calca":        np.array([0.0, 0.8, 0.2]),
    "vestido":      np.array([0.0, 0.75, 0.25]),
    "shorts":       np.array([0.0, 0.7, 0.3]),
    "sapato":       np.array([0.0, 0.6, 0.4]),
    "tenis":        np.array([0.0, 0.65, 0.35]),
    "roupa":        np.array([0.0, 0.9, 0.1]),

    # Esportes
    "futebol":      np.array([0.1, 0.0, 0.9]),
    "basquete":     np.array([0.2, 0.0, 0.8]),
    "volei":        np.array([0.3, 0.0, 0.7]),
    "natacao":      np.array([0.4, 0.0, 0.6]),
    "corrida":      np.array([0.5, 0.0, 0.5]),
    "ciclismo":     np.array([0.6, 0.0, 0.4]),
    "esporte":      np.array([0.3, 0.0, 0.7]),
}

# %%
pergunta = "Qual camisa é boa para jogar futebol e basquete"

# %%
tokens = pergunta.lower().split()

# %%
tokens
# Out:
# ['qual', 'camisa', 'é', 'boa', 'para', 'jogar', 'futebol', 'e', 'basquete']

# %%
vetores = [embeddings[token] for token in tokens if token in embeddings]

# %%
palavras_encontradas = [token for token in tokens if token in embeddings]

# %%
palavras_encontradas
# Out:
# ['camisa', 'futebol', 'basquete']

# %%
indice_vencedor = np.argmax(np.mean(vetores, axis=0))

# %%
tema = classes[indice_vencedor]
tema
# Out:
# 'esportes'
