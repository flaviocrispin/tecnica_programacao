# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviocrispin/tecnica_programacao/blob/colaborador%2FLuisReis-Caixa/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/DimCustomer.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  CustomerKey  GeographyKey  FirstName LastName   BirthDate  \
# 0           0            1           680        Jon     Yang  1966-04-08
# 1           1            2           692     Eugene    Huang  1965-05-14
# 2           2            3           493      Ruben   Torres  1965-08-12
# 3           3            4           519    Christy      Zhu  1968-02-15
# 4           4            5           706  Elizabeth  Johnson  1968-08-08
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M       90000.0            2.0                   0.0
# 1             S      M       60000.0            3.0                   3.0
# 2             M      M       60000.0            3.0                   3.0
# 3             S      F       70000.0            0.0                   0.0
# 4             S      F       80000.0            5.0                   5.0
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18869 entries, 0 to 18868
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            18869 non-null  int64
#  1   CustomerKey           18869 non-null  int64
#  2   GeographyKey          18869 non-null  int64
#  3   FirstName             18869 non-null  object
#  4   LastName              18869 non-null  object
#  5   BirthDate             18869 non-null  object
#  6   MaritalStatus         18869 non-null  object
#  7   Gender                18869 non-null  object
#  8   YearlyIncome          18869 non-null  float64
#  9   TotalChildren         18869 non-null  float64
#  10  NumberChildrenAtHome  18869 non-null  float64
#  11  Education             18869 non-null  object
#  12  Occupation            18869 non-null  object
#  13  HouseOwnerFlag        18869 non-null  float64
#  14  NumberCarsOwned       18869 non-null  float64
# ...

# %%
print (f"quantidade de linhas:{df.shape[0]}")
print (f"quantidade de colunas:{df.shape[1]}")
df.head()
# Out:
# quantidade de linhas:18869
# quantidade de colunas:15
#    Unnamed: 0  CustomerKey  GeographyKey  FirstName LastName   BirthDate  \
# 0           0            1           680        Jon     Yang  1966-04-08
# 1           1            2           692     Eugene    Huang  1965-05-14
# 2           2            3           493      Ruben   Torres  1965-08-12
# 3           3            4           519    Christy      Zhu  1968-02-15
# 4           4            5           706  Elizabeth  Johnson  1968-08-08
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M       90000.0            2.0                   0.0
# 1             S      M       60000.0            3.0                   3.0
# 2             M      M       60000.0            3.0                   3.0
# 3             S      F       70000.0            0.0                   0.0
# 4             S      F       80000.0            5.0                   5.0
#
# ...

# %%
df[['FirstName','BirthDate','YearlyIncome']]
# Out:
#           FirstName   BirthDate  YearlyIncome
# 0               Jon  1966-04-08       90000.0
# 1            Eugene  1965-05-14       60000.0
# 2             Ruben  1965-08-12       60000.0
# 3           Christy  1968-02-15       70000.0
# 4         Elizabeth  1968-08-08       80000.0
# ...             ...         ...           ...
# 18864  Not Provided  1970-02-01    10000000.0
# 18865  Not Provided  1989-02-16    10000000.0
# 18866  Not Provided  1980-07-23    10000000.0
# 18867  Not Provided  1982-08-28    10000000.0
# 18868  Not Provided  1967-06-19    10000000.0
#
# [18869 rows x 3 columns]

# %%
df_novo.head()
# Out:
#    Unnamed: 0  CustomerKey  GeographyKey  FirstName LastName  BirthDate  \
# 0           0            1           680        Jon     Yang       1966
# 1           1            2           692     Eugene    Huang       1965
# 2           2            3           493      Ruben   Torres       1965
# 3           3            4           519    Christy      Zhu       1968
# 4           4            5           706  Elizabeth  Johnson       1968
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M       90000.0            2.0                   0.0
# 1             S      M       60000.0            3.0                   3.0
# 2             M      M       60000.0            3.0                   3.0
# 3             S      F       70000.0            0.0                   0.0
# 4             S      F       80000.0            5.0                   5.0
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_10 = df_novo.head(10).copy
df_10()
# Out:
#    Unnamed: 0  CustomerKey  GeographyKey  FirstName LastName  BirthDate  \
# 0           0            1           680        Jon     Yang       1966
# 1           1            2           692     Eugene    Huang       1965
# 2           2            3           493      Ruben   Torres       1965
# 3           3            4           519    Christy      Zhu       1968
# 4           4            5           706  Elizabeth  Johnson       1968
# 5           5            6           478      Julio     Ruiz       1965
# 6           6            7           509      Janet  Alvarez       1965
# 7           7            8           568      Marco    Mehta       1964
# 8           8            9           425        Rob  Verhoff       1964
# 9           9           10           492    Shannon  Carlson       1964
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M       90000.0            2.0                   0.0
# ...

# %%
df_novo['BirthDate'] = pd.to_datetime(df_novo['BirthDate'])
df_novo['BirthDate'] = df_novo['BirthDate'].dt.year

# %%
sns.histplot(df_novo['BirthDate'], bins=20, kde=True)
plt.title('Distribuição de Idades')
sns.color_palette('colorblind')
plt.xlabel('Ano de Nascimento')
plt.ylabel('Frequência')
plt.show()
