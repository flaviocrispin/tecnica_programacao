# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviocrispin/tecnica_programacao/blob/main/aula_pandas_17_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/projetos/DimCustomer.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/DimCustomer.csv',  parse_dates=["BirthDate"], date_format="%Y-%m-%d")

# %%
def carregar_dados ():
  data = pd.read_csv('/content/drive/MyDrive/projetos/DimCustomer.csv', parse_dates=["BirthDate"], date_format="%Y-%m-%d")
  #data['BirthDate'] = pd.to_datetime(data['BirthDate'])
  data.drop('Unnamed: 0', inplace=True, axis=1)
  return data

# %%
df = carregar_dados()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18869 entries, 0 to 18868
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerKey           18869 non-null  int64
#  1   GeographyKey          18869 non-null  int64
#  2   FirstName             18869 non-null  object
#  3   LastName              18869 non-null  object
#  4   BirthDate             18869 non-null  datetime64[ns]
#  5   MaritalStatus         18869 non-null  object
#  6   Gender                18869 non-null  object
#  7   YearlyIncome          18869 non-null  float64
#  8   TotalChildren         18869 non-null  float64
#  9   NumberChildrenAtHome  18869 non-null  float64
#  10  Education             18869 non-null  object
#  11  Occupation            18869 non-null  object
#  12  HouseOwnerFlag        18869 non-null  float64
#  13  NumberCarsOwned       18869 non-null  float64
# ...

# %%
#@title Quantidade de linhas e colunas
print (f"Quantidade de linhas: {df.shape[0]}")
print (f"Quantidade de colunas: {df.shape[1]}")
# Out:
# Quantidade de linhas: 18869
# Quantidade de colunas: 15

# %%
df.head()
# Out:
#    Unnamed: 0  CustomerKey  GeographyKey  FirstName LastName   BirthDate  \
# 0           0            1           680        Jon     Yang  1966-04-08
# 1           1            2           692     Eugene    Huang  1965-05-14
# 2           2            3           493      Ruben   Torres  1965-08-12
# 3           3            4           519    Christy      Zhu  1968-02-15
# 4           4            5           706  Elizabeth  Johnson  1968-08-08
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M       90000.0            2.0                   0.0
# 1             S      M       60000.0            3.0                   3.0
# 2             M      M       60000.0            3.0                   3.0
# 3             S      F       70000.0            0.0                   0.0
# 4             S      F       80000.0            5.0                   5.0
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned
# ...

# %%
df_novo = df[['FirstName', 'BirthDate', 'MaritalStatus', 'YearlyIncome']]

# %%
df_novo.head()
# Out:
#    FirstName   BirthDate MaritalStatus  YearlyIncome
# 0        Jon  1966-04-08             M       90000.0
# 1     Eugene  1965-05-14             S       60000.0
# 2      Ruben  1965-08-12             M       60000.0
# 3    Christy  1968-02-15             S       70000.0
# 4  Elizabeth  1968-08-08             S       80000.0

# %%
df.head()
# Out:
#    Unnamed: 0  CustomerKey  GeographyKey  FirstName LastName   BirthDate  \
# 0           0            1           680        Jon     Yang  1966-04-08
# 1           1            2           692     Eugene    Huang  1965-05-14
# 2           2            3           493      Ruben   Torres  1965-08-12
# 3           3            4           519    Christy      Zhu  1968-02-15
# 4           4            5           706  Elizabeth  Johnson  1968-08-08
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M       90000.0            2.0                   0.0
# 1             S      M       60000.0            3.0                   3.0
# 2             M      M       60000.0            3.0                   3.0
# 3             S      F       70000.0            0.0                   0.0
# 4             S      F       80000.0            5.0                   5.0
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned
# ...

# %%
novodf = df.copy()

# %%
df['BirthDate'] = pd.to_datetime(df['BirthDate'])

# %%
df.head()
# Out:
#    Unnamed: 0  CustomerKey  GeographyKey  FirstName LastName  BirthDate  \
# 0           0            1           680        Jon     Yang 1966-04-08
# 1           1            2           692     Eugene    Huang 1965-05-14
# 2           2            3           493      Ruben   Torres 1965-08-12
# 3           3            4           519    Christy      Zhu 1968-02-15
# 4           4            5           706  Elizabeth  Johnson 1968-08-08
#
#   MaritalStatus Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M      M       90000.0            2.0                   0.0
# 1             S      M       60000.0            3.0                   3.0
# 2             M      M       60000.0            3.0                   3.0
# 3             S      F       70000.0            0.0                   0.0
# 4             S      F       80000.0            5.0                   5.0
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18869 entries, 0 to 18868
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            18869 non-null  int64
#  1   CustomerKey           18869 non-null  int64
#  2   GeographyKey          18869 non-null  int64
#  3   FirstName             18869 non-null  object
#  4   LastName              18869 non-null  object
#  5   BirthDate             18869 non-null  datetime64[ns]
#  6   MaritalStatus         18869 non-null  object
#  7   Gender                18869 non-null  object
#  8   YearlyIncome          18869 non-null  float64
#  9   TotalChildren         18869 non-null  float64
#  10  NumberChildrenAtHome  18869 non-null  float64
#  11  Education             18869 non-null  object
#  12  Occupation            18869 non-null  object
#  13  HouseOwnerFlag        18869 non-null  float64
# ...

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df.head()
# Out:
#    CustomerKey  GeographyKey  FirstName LastName  BirthDate MaritalStatus  \
# 0            1           680        Jon     Yang 1966-04-08             M
# 1            2           692     Eugene    Huang 1965-05-14             S
# 2            3           493      Ruben   Torres 1965-08-12             M
# 3            4           519    Christy      Zhu 1968-02-15             S
# 4            5           706  Elizabeth  Johnson 1968-08-08             S
#
#   Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  Education  \
# 0      M       90000.0            2.0                   0.0  Bachelors
# 1      M       60000.0            3.0                   3.0  Bachelors
# 2      M       60000.0            3.0                   3.0  Bachelors
# 3      F       70000.0            0.0                   0.0  Bachelors
# 4      F       80000.0            5.0                   5.0  Bachelors
#
#      Occupation  HouseOwnerFlag  NumberCarsOwned
# ...

# %%
df.describe()
# Out:
#         CustomerKey  GeographyKey                      BirthDate  \
# count  18869.000000  18869.000000                          18869
# mean    9440.631459    574.910435  1962-05-05 06:14:05.958980352
# min        1.000000    423.000000            1910-08-13 00:00:00
# 25%     4718.000000    506.000000            1954-11-14 00:00:00
# 50%     9435.000000    568.000000            1963-11-02 00:00:00
# 75%    14152.000000    645.000000            1970-12-27 00:00:00
# max    19145.000000    952.000000            1990-12-27 00:00:00
# std     5456.841811     84.163867                            NaN
#
#        YearlyIncome  TotalChildren  NumberChildrenAtHome  HouseOwnerFlag  \
# count  1.886900e+04   18869.000000          18869.000000    18869.000000
# mean   2.601749e+05       1.856219              1.034077        0.673274
# min    1.000000e+04       0.000000              0.000000        0.000000
# 25%    3.000000e+04       0.000000              0.000000        0.000000
# ...

# %%
df['novaocoluna'] = 1

# %%
df.head()
# Out:
#    CustomerKey  GeographyKey  FirstName LastName  BirthDate MaritalStatus  \
# 0            1           680        Jon     Yang 1966-04-08             M
# 1            2           692     Eugene    Huang 1965-05-14             S
# 2            3           493      Ruben   Torres 1965-08-12             M
# 3            4           519    Christy      Zhu 1968-02-15             S
# 4            5           706  Elizabeth  Johnson 1968-08-08             S
#
#   Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  Education  \
# 0      M       90000.0            2.0                   0.0  Bachelors
# 1      M       60000.0            3.0                   3.0  Bachelors
# 2      M       60000.0            3.0                   3.0  Bachelors
# 3      F       70000.0            0.0                   0.0  Bachelors
# 4      F       80000.0            5.0                   5.0  Bachelors
#
#      Occupation  HouseOwnerFlag  NumberCarsOwned  novaocoluna
# ...

# %%
df['NumberCarsOwned'].mean()
# Out:
# np.float64(1.5137527160951825)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    9525
# F    9344
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18869 entries, 0 to 18868
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            18869 non-null  int64
#  1   CustomerKey           18869 non-null  int64
#  2   GeographyKey          18869 non-null  int64
#  3   FirstName             18869 non-null  object
#  4   LastName              18869 non-null  object
#  5   BirthDate             18869 non-null  datetime64[ns]
#  6   MaritalStatus         18869 non-null  object
#  7   Gender                18869 non-null  object
#  8   YearlyIncome          18869 non-null  float64
#  9   TotalChildren         18869 non-null  float64
#  10  NumberChildrenAtHome  18869 non-null  float64
#  11  Education             18869 non-null  object
#  12  Occupation            18869 non-null  object
#  13  HouseOwnerFlag        18869 non-null  float64
# ...

# %%
df['BirthDate'] = pd.to_datetime(df['BirthDate'])

# %%
#@title Histograma
def gerar_grafico(nome_coluna):
  sns.histplot(df[nome_coluna], bins=20, kde=True)
  plt.title('Histograma')
  plt.show()

# %%
#@title Gerar gráfico
gerar_grafico('BirthDate')

# %%
df_alterado = df['Gender'].replace('F', 'Mulheres', inplace=True)
df['Gender'].replace('M', 'Homens', inplace=True)
# Out:
# /tmp/ipykernel_1583/3469107989.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_alterado = df['Gender'].replace('F', 'Mulheres', inplace=True)
# /tmp/ipykernel_1583/3469107989.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  CustomerKey  GeographyKey  FirstName LastName   BirthDate  \
# 0           0            1           680        Jon     Yang  1966-04-08
# 1           1            2           692     Eugene    Huang  1965-05-14
# 2           2            3           493      Ruben   Torres  1965-08-12
# 3           3            4           519    Christy      Zhu  1968-02-15
# 4           4            5           706  Elizabeth  Johnson  1968-08-08
#
#   MaritalStatus    Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0             M    Homens       90000.0            2.0                   0.0
# 1             S    Homens       60000.0            3.0                   3.0
# 2             M    Homens       60000.0            3.0                   3.0
# 3             S  Mulheres       70000.0            0.0                   0.0
# 4             S  Mulheres       80000.0            5.0                   5.0
#
#    Education    Occupation  HouseOwnerFlag  NumberCarsOwned
# ...

# %%
#@title Gráfico de barras
sns.barplot(x='Gender', y='CustomerKey', data=df)
plt.title('Quantidade de clientes por gênero')
plt.xlabel("Gênero")
plt.ylabel("Frequência")
plt.savefig('/content/drive/MyDrive/projetos/grafico_barra.png')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    9525
# F    9344
# Name: count, dtype: int64
