# %%
# %pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.6 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/12.6 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/12.6 MB 2.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/12.6 MB 1.6 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/12.6 MB 1.8 MB/s eta 0:00:06
#    ------- -------------------------------- 2.4/12.6 MB 1.8 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/12.6 MB 1.7 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/12.6 MB 1.7 MB/s eta 0:00:06
#    --------- ------------------------------ 2.9/12.6 MB 1.3 MB/s eta 0:00:08
# ...

# %%
import numpy as np

# %%
lista = [1, 2, 3, 4, 5]

# %%
vetor = np.array([1, 2, 3, 4, 5])
